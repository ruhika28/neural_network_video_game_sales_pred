# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential,load_model
from keras.layers import *

# Load training data set from CSV file
training_data_df = pd.read_csv("sales_data_training.csv")

# Load testing data set from CSV file
test_data_df = pd.read_csv("sales_data_test.csv")

# Data needs to be scaled to a small range like 0 to 1 for the neural
# network to work well.
scaler = MinMaxScaler(feature_range=(0, 1))

# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
scaled_testing = scaler.transform(test_data_df)

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))

# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("sales_data_training_scaled.csv", index=False)
scaled_testing_df.to_csv("sales_data_testing_scaled.csv", index=False)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# Note: total_earnings values were scaled by multiplying by 0.0000036968 and adding -0.115913

# %%
train_df=pd.read_csv("sales_data_training_scaled.csv")

# %%
display(train_df)
# Out:
#      critic_rating  is_action  is_exclusive_to_us  is_portable  \
# 0         0.500000        1.0                 0.0          1.0
# 1         0.833333        0.0                 0.0          0.0
# 2         0.333333        0.0                 0.0          0.0
# 3         0.833333        1.0                 0.0          0.0
# 4         0.666667        1.0                 0.0          1.0
# 5         0.666667        0.0                 0.0          0.0
# 6         0.000000        1.0                 0.0          0.0
# 7         0.833333        0.0                 0.0          1.0
# 8         0.500000        0.0                 0.0          1.0
# 9         0.166667        1.0                 0.0          0.0
# 10        0.833333        1.0                 0.0          1.0
# 11        0.500000        0.0                 0.0          0.0
# 12        0.500000        0.0                 0.0          0.0
# 13        0.666667        0.0                 0.0          0.0
# ...

# %%
X=train_df.drop("total_earnings", axis=1)

# %%
Y=train_df[["total_earnings"]].values

# %%
#create the layers

# %%
model=Sequential()
model.add(Dense(50,input_dim=9,activation="relu"))

# %%
model.add(Dense(100,activation='relu'))

# %%
model.add(Dense(50, activation='relu'))

# %%
model.add(Dense(1, activation='linear'))

# %% [markdown]
# # build the model

# %%
model.compile(loss='mse',optimizer='adam')

# %%
model.fit(X,Y,epochs=50,shuffle=True,verbose=2)
# Out:
# Epoch 1/50
#  - 1s - loss: 0.0267
# Epoch 2/50
#  - 0s - loss: 0.0033
# Epoch 3/50
#  - 0s - loss: 0.0010
# Epoch 4/50
#  - 0s - loss: 5.4340e-04
# Epoch 5/50
#  - 0s - loss: 3.5158e-04
# Epoch 6/50
#  - 0s - loss: 2.4999e-04
# Epoch 7/50
#  - 0s - loss: 2.0507e-04
# Epoch 8/50
#  - 0s - loss: 1.5112e-04
# Epoch 9/50
#  - 0s - loss: 1.2326e-04
# Epoch 10/50
#  - 0s - loss: 1.1266e-04
# Epoch 11/50
#  - 0s - loss: 1.0925e-04
# Epoch 12/50
#  - 0s - loss: 8.4430e-05
# Epoch 13/50
#  - 0s - loss: 6.8183e-05
# Epoch 14/50
#  - 0s - loss: 5.6058e-05
# Epoch 15/50
#  - 0s - loss: 5.0954e-05
# Epoch 16/50
#  - 0s - loss: 4.5861e-05
# Epoch 17/50
#  - 0s - loss: 4.7078e-05
# Epoch 18/50
#  - 0s - loss: 4.0078e-05
# Epoch 19/50
#  - 0s - loss: 4.3952e-05
# Epoch 20/50
#  - 0s - loss: 3.5385e-05
# Epoch 21/50
#  - 0s - loss: 3.7169e-05
# Epoch 22/50
#  - 0s - loss: 3.4255e-05
# Epoch 23/50
#  - 0s - loss: 3.1519e-05
# Epoch 24/50
#  - 0s - loss: 3.1288e-05
# Epoch 25/50
# ...

# %% [markdown]
# #Load the test data

# %%
test_df=pd.read_csv("sales_data_test_scaled.csv")

# %%
display(test_df)
# Out:
#      critic_rating  is_action  is_exclusive_to_us  is_portable  \
# 0         0.500000        1.0                 1.0          1.0
# 1         0.166667        0.0                 0.0          0.0
# 2         0.500000        0.0                 0.0          0.0
# 3         0.666667        1.0                 1.0          0.0
# 4         0.000000        1.0                 0.0          1.0
# 5         0.500000        1.0                 0.0          1.0
# 6         0.666667        1.0                 0.0          0.0
# 7         0.500000        1.0                 1.0          1.0
# 8         0.666667        1.0                 1.0          0.0
# 9         0.166667        0.0                 1.0          0.0
# 10        1.000000        1.0                 0.0          0.0
# 11        0.666667        1.0                 0.0          0.0
# 12        0.500000        0.0                 1.0          0.0
# 13        0.666667        0.0                 0.0          1.0
# ...

# %%
X_test=test_df.drop("total_earnings",axis=1).values
Y_test=test_df[["total_earnings"]].values

# %%
test_error_rate=model.evaluate(X_test,Y_test,verbose=0)

# %% [markdown]
# print(format.test_error_rate)

# %% [markdown]
# # Make a prediction on the total earning using a new record having the  same defining attributes

# %%
X_predict=pd.read_csv("proposed_new_product.csv")

# %%
prediction_of_video_game_earnings=model.predict(X_predict)

# %%
prediction_of_video_game_earnings=prediction_of_video_game_earnings[0][0]

# %%
prediction_of_video_game_earnings=prediction_of_video_game_earnings+0.1159

# %%
prediction_of_video_game_earnings=prediction_of_video_game_earnings/0.0000036968

# %% [markdown]
# print(format(prediction_of_video_game_earnings))

# %% [markdown]
# # neural  net predicted that  $261637.3732914994 would be the yearly earning of the proposed game after having 50 epochs

# %%
#saving the model in keras for another  program

model.save("nn_train.h5")#binary python array data

print("model_saved")
# Out:
# model_saved

# %%
#So  you  have to just load the neural  net and work  with the predicting the op no need to  declare teh  neurl net since its aldready trained

# %%
model_import=load_model("nn_train.h5")
X_predict_proposed=pd.read_csv("proposed_new_product.csv")
prediction_of_video_game_earnings_prop=model.predict(X_predict_proposed)
prediction_of_video_game_earnings_prop=prediction_of_video_game_earnings_prop[0][0]
prediction_of_video_game_earnings_prop=prediction_of_video_game_earnings_prop+0.1159
prediction_of_video_game_earnings_prop=prediction_of_video_game_earnings_prop/0.0000036968
print(format(prediction_of_video_game_earnings_prop))
# Out:
# 261637.3732914994

# %%
#same  result
